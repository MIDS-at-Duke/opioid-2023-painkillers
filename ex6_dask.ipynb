# %%
import pandas as pd
import numpy as np
from dask.distributed import Client

client = Client()
client
# Out:
# /Users/farazjawed/miniconda3/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 52958 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:52959' processes=4 threads=8, memory=8.00 GiB>

# %%
import dask.dataframe as dd

selected_columns = [
    "BUYER_STATE",
    "BUYER_COUNTY",
    "TRANSACTION_DATE",
    "MME",
]

# %%
opiod_df = dd.read_csv(
    "arcos_all_washpost.tsv",
    sep="\t",
    usecols=selected_columns,
)

opiod_df["Year"] = dd.to_datetime(
    opiod_df["TRANSACTION_DATE"], format="%Y-%m-%d"
).dt.year

opiod_df = (
    opiod_df.groupby(["BUYER_COUNTY", "BUYER_STATE", "Year"])["MME"].sum().reset_index()
)

result_df = opiod_df.compute()

# %%
result_df
# Out:
#       BUYER_COUNTY BUYER_STATE  Year           MME
# 0            ADAMS          IN  2006  3.290648e+06
# 1            ADAMS          IN  2007  3.786557e+06
# 2            ADAMS          IN  2008  3.946667e+06
# 3            ADAMS          IN  2009  4.369181e+06
# 4            ADAMS          IN  2010  5.176397e+06
# ...            ...         ...   ...           ...
# 43147       EUREKA          NV  2007  4.540500e+02
# 43148    WABAUNSEE          KS  2013  3.027000e+02
# 43149      LINCOLN          ID  2006  1.195665e+03
# 43150        ADAMS          ID  2008  3.632400e+03
# 43151        BOISE          ID  2011  1.452960e+03
#
# [43152 rows x 4 columns]

# %%
import os

print(f"I have {os.cpu_count()} logical cores.")
# Out:
# I have 8 logical cores.
